# %%
import pandas as pd
import numpy as np

# %%
train=pd.read_csv('walmart_train.csv')
feature=pd.read_csv('walmart_features.csv')
store=pd.read_csv('walmart_stores.csv')
test=pd.read_csv('walmart_test.csv')

# %%
train=train.merge(feature,how='left')

# %%
train=train.merge(store,how='left')
train
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday  Temperature  \
# 0           1     1  2010-02-05      24924.50      False        42.31
# 1           1     1  2010-02-12      46039.49       True        38.51
# 2           1     1  2010-02-19      41595.55      False        39.93
# 3           1     1  2010-02-26      19403.54      False        46.63
# 4           1     1  2010-03-05      21827.90      False        46.50
# ...       ...   ...         ...           ...        ...          ...
# 421565     45    98  2012-09-28        508.37      False        64.88
# 421566     45    98  2012-10-05        628.10      False        64.89
# 421567     45    98  2012-10-12       1061.02      False        54.47
# 421568     45    98  2012-10-19        760.01      False        56.47
# 421569     45    98  2012-10-26       1076.80      False        58.85
#
#         Fuel_Price  MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5  \
# ...

# %%
train.isnull().mean()
# Out:
# Store           0.000000
# Dept            0.000000
# Date            0.000000
# Weekly_Sales    0.000000
# IsHoliday       0.000000
# Temperature     0.000000
# Fuel_Price      0.000000
# MarkDown1       0.642572
# MarkDown2       0.736110
# MarkDown3       0.674808
# MarkDown4       0.679847
# MarkDown5       0.640790
# CPI             0.000000
# Unemployment    0.000000
# Type            0.000000
# Size            0.000000
# dtype: float64

# %%
train.describe()
# Out:
#                Store           Dept   Weekly_Sales    Temperature  \
# count  421570.000000  421570.000000  421570.000000  421570.000000
# mean       22.200546      44.260317   15981.258123      60.090059
# std        12.785297      30.492054   22711.183519      18.447931
# min         1.000000       1.000000   -4988.940000      -2.060000
# 25%        11.000000      18.000000    2079.650000      46.680000
# 50%        22.000000      37.000000    7612.030000      62.090000
# 75%        33.000000      74.000000   20205.852500      74.280000
# max        45.000000      99.000000  693099.360000     100.140000
#
#           Fuel_Price      MarkDown1      MarkDown2      MarkDown3  \
# count  421570.000000  150681.000000  111248.000000  137091.000000
# mean        3.361027    7246.420196    3334.628621    1439.421384
# std         0.458515    8291.221345    9475.357325    9623.078290
# min         2.472000       0.270000    -265.760000     -29.100000
# ...

# %%
#for mark in train.columns[7:12]:
 #   plt.figure(figsize=(8,6))
  #  train[mark].plot(kind='kde')

# %%
for mark in train.columns[7:12]:
    train[mark+'_zero']=train[mark].fillna(0)

# %%
for mark in train.columns[7:12]:
    mean=train[mark].mean()
    train[mark+'_mean']=train[mark].fillna(mean)

# %%
for mark in train.columns[7:12]:
    median=train[mark].median()
    train[mark+'_median']=train[mark].fillna(median)

# %%
for mark in train.columns[7:12]:
    mode=train[mark].mode()
    train[mark+'_mode']=train[mark].fillna(mode)

# %%
for mark in train.columns[7:12]:
    mode=train[mark].mode()
    train[mark+'_mode']=train[mark].fillna(mode)

# %%
for mark in train.columns[7:12]:
    extr_outlier=train[mark].mean()+3*train[mark].std()
    train[mark+'ext_outlier']=train[mark].fillna(extr_outlier)

# %%
for mark in train.columns[7:12]:
    lowe_outlier=train[mark].mean()-3*train[mark].std()
    train[mark+'low_outlier']=train[mark].fillna(lowe_outlier)

# %%
#for mark in train.columns[7:12]:
 #   plt.figure(figsize=(8,6))
  #  train[mark].plot(kind='kde',color='balck')
   # train[mark+'_mean'].plot(kind='kde',color='red')

# %%
train.describe()
# Out:
#                Store           Dept   Weekly_Sales    Temperature  \
# count  421570.000000  421570.000000  421570.000000  421570.000000
# mean       22.200546      44.260317   15981.258123      60.090059
# std        12.785297      30.492054   22711.183519      18.447931
# min         1.000000       1.000000   -4988.940000      -2.060000
# 25%        11.000000      18.000000    2079.650000      46.680000
# 50%        22.000000      37.000000    7612.030000      62.090000
# 75%        33.000000      74.000000   20205.852500      74.280000
# max        45.000000      99.000000  693099.360000     100.140000
#
#           Fuel_Price      MarkDown1      MarkDown2      MarkDown3  \
# count  421570.000000  150681.000000  111248.000000  137091.000000
# mean        3.361027    7246.420196    3334.628621    1439.421384
# std         0.458515    8291.221345    9475.357325    9623.078290
# min         2.472000       0.270000    -265.760000     -29.100000
# ...

# %%
train
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday  Temperature  \
# 0           1     1  2010-02-05      24924.50      False        42.31
# 1           1     1  2010-02-12      46039.49       True        38.51
# 2           1     1  2010-02-19      41595.55      False        39.93
# 3           1     1  2010-02-26      19403.54      False        46.63
# 4           1     1  2010-03-05      21827.90      False        46.50
# ...       ...   ...         ...           ...        ...          ...
# 421565     45    98  2012-09-28        508.37      False        64.88
# 421566     45    98  2012-10-05        628.10      False        64.89
# 421567     45    98  2012-10-12       1061.02      False        54.47
# 421568     45    98  2012-10-19        760.01      False        56.47
# 421569     45    98  2012-10-26       1076.80      False        58.85
#
#         Fuel_Price  MarkDown1  MarkDown2  MarkDown3  ...  \
# 0            2.572        NaN        NaN        NaN  ...
# ...
